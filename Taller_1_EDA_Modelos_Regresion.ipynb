# %% [markdown]
# # 🏠 Taller: Análisis y Modelamiento de Datos de Airbnb en Barcelona 🏙️
#
# ---
#
# ## ✨ Introducción
#
# En este taller trabajaremos con un conjunto de datos reales de Airbnb que contiene información detallada sobre las propiedades disponibles para alquiler en Barcelona. Los datos incluyen características de los alojamientos, detalles de los anfitriones, precios, disponibilidad, y reseñas. Este contexto real te permitirá aplicar técnicas fundamentales de limpieza, exploración, análisis y modelamiento de datos para obtener insights y construir un **estimador de precio para las propiedades listadas**.
#
# ---
#
# ## 📋 Reglas de juego
#
# - 👥 Este taller se debe presentar en grupos de máximo **3 estudiantes**
# - ❌ Cualquier intento de copia que se identifique entre 2 o más grupos inmediatamente otorga una calificación de **0.0**
# - ⏰ La fecha de entrega será el día **21 de Agosto de 2025 antes de media noche**
#
# ---
#
# ## 🎯 Objetivo
#
# El objetivo principal es desarrollar un flujo completo de análisis de datos que abarque desde la limpieza y manejo, la identificación y tratamiento de valores atípicos, hasta la creación de un **modelo predictivo para estimar el precio de las propiedades en Airbnb Barcelona**.
#
# Para lograr esto, deberás:
#
# - 🧹 Procesar y limpiar el conjunto de datos.
# - 🔎 Realizar análisis exploratorio descriptivo de las variables.
# - 🛠️ Imputar datos faltantes donde sea necesario.
# - 🚩 Identificar y analizar datos atípicos (outliers).
# - 📈 Construir un modelo predictivo (regresión u otro) para estimar el precio de los listings.
#
# ---
#
# ## 📚 Descripción de Variables Clave
#
# | 🏷️ Variable                              | 📝 Descripción                                               |
# |-------------------------------------|-----------------------------------------------------------|
# | `id`                                | Identificador único de la propiedad                       |
# | `listing_url`                       | URL del anuncio en Airbnb                                 |
# | `scrape_id`                        | Identificador de la extracción del dato                  |
# | `last_scraped`                     | Fecha de la última extracción                             |
# | `source`                          | Fuente de los datos                                       |
# | `name`                            | Nombre del listado                                        |
# | `description`                     | Descripción del alojamiento                               |
# | `neighborhood_overview`            | Descripción del vecindario                                |
# | `picture_url`                     | URL de la imagen principal                                |
# | `host_id`                        | Identificador del anfitrión                               |
# | `host_url`                       | URL del perfil del anfitrión                              |
# | `host_name`                      | Nombre del anfitrión                                     |
# | `host_since`                     | Fecha desde que el anfitrión está activo                 |
# | `host_location`                  | Ubicación del anfitrión                                  |
# | `host_about`                    | Descripción del anfitrión                                |
# | `host_response_time`            | Tiempo promedio de respuesta del anfitrión               |
# | `host_response_rate`            | Porcentaje de respuestas del anfitrión                   |
# | `host_acceptance_rate`          | Porcentaje de aceptación de solicitudes                   |
# | `host_is_superhost`             | Indicador si el anfitrión es superhost                    |
# | `host_thumbnail_url`            | URL de la miniatura del anfitrión                         |
# | `host_picture_url`              | URL de la foto del anfitrión                              |
# | `host_neighbourhood`            | Vecindario del anfitrión                                  |
# | `host_listings_count`           | Número de listados del anfitrión                          |
# | `host_total_listings_count`     | Total de listados del anfitrión (incluye otros tipos)    |
# | `host_verifications`            | Métodos de verificación del anfitrión                     |
# | `host_has_profile_pic`          | Indicador si tiene foto de perfil                         |
# | `host_identity_verified`        | Indicador de identidad verificada                         |
# | `neighbourhood`                 | Vecindario                                               |
# | `neighbourhood_cleansed`        | Vecindario limpio                                        |
# | `neighbourhood_group_cleansed`  | Grupo del vecindario limpio                              |
# | `latitude`                     | Latitud                                                 |
# | `longitude`                    | Longitud                                                |
# | `property_type`                | Tipo de propiedad                                       |
# | `room_type`                   | Tipo de habitación                                     |
# | `accommodates`                | Número de personas que puede alojar                    |
# | `bathrooms`                   | Número de baños                                       |
# | `bathrooms_text`              | Descripción de baños                                  |
# | `bedrooms`                   | Número de habitaciones                               |
# | `beds`                       | Número de camas                                    |
# | `amenities`                  | Lista de amenidades                                |
# | `price`                     | Precio por noche                                  |
# | `minimum_nights`            | Número mínimo de noches                             |
# | `maximum_nights`            | Número máximo de noches                             |
# | `minimum_minimum_nights`    | Mínimo de la mínima cantidad de noches permitidas  |
# | `maximum_minimum_nights`    | Máximo de la mínima cantidad de noches permitidas  |
# | `minimum_maximum_nights`    | Mínimo de la máxima cantidad de noches permitidas  |
# | `maximum_maximum_nights`    | Máximo de la máxima cantidad de noches permitidas  |
# | `minimum_nights_avg_ntm`    | Promedio de mínimas noches por mes                   |
# | `maximum_nights_avg_ntm`    | Promedio de máximas noches por mes                   |
# | `calendar_updated`          | Fecha de actualización del calendario                |
# | `has_availability`          | Indicador de disponibilidad                           |
# | `availability_30`           | Disponibilidad en los próximos 30 días                |
# | `availability_60`           | Disponibilidad en los próximos 60 días                |
# | `availability_90`           | Disponibilidad en los próximos 90 días                |
# | `availability_365`          | Disponibilidad en los próximos 365 días               |
# | `calendar_last_scraped`     | Fecha del último scraping del calendario               |
# | `number_of_reviews`         | Número total de reseñas                                |
# | `number_of_reviews_ltm`     | Número de reseñas últimos 12 meses                     |
# | `number_of_reviews_l30d`    | Número de reseñas últimos 30 días                       |
# | `availability_eoy`          | Disponibilidad para fin de año                          |
# | `number_of_reviews_ly`      | Número de reseñas del año pasado                        |
# | `estimated_occupancy_l365d`| Estimación de ocupación últimos 365 días               |
# | `estimated_revenue_l365d`  | Estimación de ingresos últimos 365 días                |
# | `first_review`              | Fecha de la primera reseña                              |
# | `last_review`               | Fecha de la última reseña                               |
# | `review_scores_rating`      | Calificación promedio                                  |
# | `review_scores_accuracy`    | Calificación de precisión                              |
# | `review_scores_cleanliness` | Calificación de limpieza                               |
# | `review_scores_checkin`     | Calificación de check-in                               |
# | `review_scores_communication` | Calificación de comunicación                         |
# | `review_scores_location`    | Calificación de ubicación                              |
# | `review_scores_value`       | Calificación de valor                                  |
# | `license`                   | Licencia (si aplica)                                   |
# | `instant_bookable`          | Indicador si se puede reservar instantáneamente       |
# | `calculated_host_listings_count` | Número calculado de listados del anfitrión       |
# | `calculated_host_listings_count_entire_homes` | Número de listados casas completas        |
# | `calculated_host_listings_count_private_rooms` | Número de listados habitaciones privadas |
# | `calculated_host_listings_count_shared_rooms` | Número de listados habitaciones compartidas |
# | `reviews_per_month`         | Promedio de reseñas por mes                            |
#
# > *Nota: algunas variables pueden contener valores faltantes o formatos heterogéneos que requerirán tratamiento.* ⚠️
#
# ---
#
# ## ❓ Puntos / Preguntas a Resolver
#
# 1. **Carga y limpieza de datos:**
#    - Carga el archivo `listings.csv.gz` y revisa las primeras filas.
#    - Identifica variables con valores faltantes, duplicados o inconsistentes.
#    - Realiza una limpieza básica:
#      - Corrige formatos de fecha.
#      - Convierte columnas numéricas que estén como texto.
#      - Maneja valores faltantes: decide si imputar o eliminar observaciones.
#
# 2. **Análisis exploratorio de datos:**
#    - Describe la distribución de variables numéricas relevantes (`price`, `bedrooms`, `accommodates`, `number_of_reviews`, etc.).
#    - Realiza gráficos para entender la distribución y relación entre variables (histogramas, boxplots, scatterplots).
#    - **Opcional:** Examina la distribución geográfica usando `latitude` y `longitude`.
#
# 3. **Imputación y tratamiento de valores faltantes:**
#    - Analiza qué variables tienen datos faltantes y sus proporciones.
#    - Realiza una imputación adecuada y justifica la técnica usada.
#
# 4. **Identificación y análisis de outliers:**
#    - Identifica valores atípicos en variables clave (`price`, `bedrooms`, `accommodates`).
#    - Decide cómo tratarlos (transformación, eliminación o capping).
#
# 5. **Construcción de modelo predictivo para `price`:**
#    - Define la variable objetivo y variables predictoras relevantes.
#    - Entrena un modelo de regresión lineal.
#    - Evalúa desempeño con métricas como $R^2$, RMSE, MAE, etc.
#    - Interpreta coeficientes o importancia de variables.
#    - **Opcional:** Explora modelos más complejos para mejorar desempeño (calificación extra).
#
# 6. **Conclusiones:**
#    - Resume hallazgos importantes.
#    - Propón recomendaciones para estrategia de precios o gestión en Airbnb.
#
# ---
#
# ## 💡 Recursos Sugeridos
#
# - 🐼 Pandas para manipulación y limpieza de datos.
# - 📊 Matplotlib y Seaborn para visualización.
# - 🤖 Scikit-learn para modelamiento.
# - 🗺️ Geopandas o Folium para visualización geográfica.
# - 🛠️ Técnicas de imputación: media, mediana, KNN, regresión.
# - 🔍 Detección de outliers con boxplots, IQR o Isolation Forest.
#
# ---
#
# 🚀 **¡Manos a la obra y éxito en el análisis!** 🎉📈

# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # Show all columns

df = pd.read_csv('listings.csv.gz', compression='gzip')
df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   18674   https://www.airbnb.com/rooms/18674  20250612050654   2025-06-21
# 1   23197   https://www.airbnb.com/rooms/23197  20250612050654   2025-06-23
# 2   32711   https://www.airbnb.com/rooms/32711  20250612050654   2025-06-22
# 3   34241   https://www.airbnb.com/rooms/34241  20250612050654   2025-06-22
# 4  347824  https://www.airbnb.com/rooms/347824  20250612050654   2025-06-22
#
#         source                                               name  \
# 0  city scrape    Huge flat for 8 people close to Sagrada Familia
# 1  city scrape  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2  city scrape                   Sagrada Familia area - Còrsega 1
# 3  city scrape   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4  city scrape  Ideal Happy Location Barceloneta Beach, Old Town!
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Beautiful and Spacious Apartment with Large Te...
# 2  A lovely two bedroom apartment only 250 m from...
# 3  Located in close proximity to Plaza Real and L...
# 4  Please send us a message to confirm availabili...
#
#                                neighborhood_overview  \
# 0  Apartment in Barcelona located in the heart of...
# 1  Strategically located in the Parc del Fòrum, a...
# 2  What's nearby  <br />This apartment is located...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/13031453/413c...    71615
# 1  https://a0.muscache.com/pictures/miso/Hosting-...    90417
# 2  https://a0.muscache.com/pictures/357b25e4-f414...   135703
# 3  https://a0.muscache.com/pictures/2437facc-2fe7...    73163
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  1447144
#
#                                     host_url            host_name  host_since  \
# 0    https://www.airbnb.com/users/show/71615        Mireia  Maria  2010-01-19
# 1    https://www.airbnb.com/users/show/90417       Etain (Marnie)  2010-03-09
# 2   https://www.airbnb.com/users/show/135703                 Nick  2010-05-31
# 3    https://www.airbnb.com/users/show/73163               Andres  2010-01-24
# 4  https://www.airbnb.com/users/show/1447144  Acomodis Apartments  2011-11-27
#
#       host_location                                         host_about  \
# 0  Barcelona, Spain  We are Mireia (47) & Maria (49), two multiling...
# 1  Catalonia, Spain  Hi there,\n\nI’m marnie, originally from Austr...
# 2  Barcelona, Spain  I'm Nick your English host in Barcelona.\r\n\r...
# 3  Barcelona, Spain  Hello I am a Professional designer, a traveler...
# 4  Barcelona, Spain  Apartamentos ACOMODIS en Barcelona\n\nSomos un...
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0     within an hour                96%                  91%
# 1     within an hour               100%                  96%
# 2     within an hour               100%                 100%
# 3     within an hour                80%                  94%
# 4     within an hour                87%                  28%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/pictures/user/User/...
# 1                 t  https://a0.muscache.com/im/pictures/user/44b56...
# 2                 f  https://a0.muscache.com/im/users/135703/profil...
# 3                 f  https://a0.muscache.com/im/pictures/user/9cbe7...
# 4                 f  https://a0.muscache.com/im/pictures/user/f1ba6...
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/pictures/user/User/...
# 1  https://a0.muscache.com/im/pictures/user/44b56...
# 2  https://a0.muscache.com/im/users/135703/profil...
# 3  https://a0.muscache.com/im/pictures/user/9cbe7...
# 4  https://a0.muscache.com/im/pictures/user/f1ba6...
#
#                 host_neighbourhood  host_listings_count  \
# 0               la Sagrada Família                 44.0
# 1            El Besòs i el Maresme                  6.0
# 2  Camp d'en Grassot i Gràcia Nova                  3.0
# 3                         El Gòtic                  5.0
# 4                     El Poble-sec                356.0
#
#    host_total_listings_count                host_verifications  \
# 0                       46.0                ['email', 'phone']
# 1                        9.0                ['email', 'phone']
# 2                       15.0  ['email', 'phone', 'work_email']
# 3                        5.0  ['email', 'phone', 'work_email']
# 4                      565.0                ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      t
# 3                    t                      t
# 4                    t                      t
#
#                            neighbourhood              neighbourhood_cleansed  \
# 0                   Barcelona, CT, Spain                  la Sagrada Família
# 1  Sant Adria de Besos, Barcelona, Spain               el Besòs i el Maresme
# 2            Barcelona, Catalonia, Spain  el Camp d'en Grassot i Gràcia Nova
# 3                                    NaN                      el Barri Gòtic
# 4                                    NaN                      la Barceloneta
#
#   neighbourhood_group_cleansed   latitude  longitude       property_type  \
# 0                     Eixample  41.405560    2.17262  Entire rental unit
# 1                   Sant Martí  41.412432    2.21975  Entire rental unit
# 2                       Gràcia  41.405660    2.17015  Entire rental unit
# 3                 Ciutat Vella  41.380620    2.17517        Entire condo
# 4                 Ciutat Vella  41.376400    2.19102  Entire rental unit
#
#          room_type  accommodates  bathrooms bathrooms_text  bedrooms  beds  \
# 0  Entire home/apt             8        2.0        2 baths       3.0   6.0
# 1  Entire home/apt             5        2.0        2 baths       3.0   4.0
# 2  Entire home/apt             6        1.5      1.5 baths       2.0   3.0
# 3  Entire home/apt             2        1.0         1 bath       1.0   1.0
# 4  Entire home/apt             3        1.0         1 bath       1.0   3.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["30 inch TV", "AC - split type ductless syste...  $232.00               1
# 1  ["Bed linens", "Ceiling fan", "Oven", "AC - sp...  $382.00               3
# 2  ["Oven", "AC - split type ductless system", "S...  $186.00               1
# 3  ["Bed linens", "Oven", "Dishwasher", "Hot wate...  $131.00              31
# 4  ["Bed linens", "Hot water", "High chair", "Coo...  $285.00               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                     1.0                     5.0
# 1              32                     2.0                     7.0
# 2              31                     1.0                     1.0
# 3             180                    31.0                    31.0
# 4             330                     2.0                     2.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                   999.0                   999.0                     2.2
# 1                  1125.0                  1125.0                     3.3
# 2                    31.0                    31.0                     1.0
# 3                   180.0                   180.0                    31.0
# 4                   330.0                   330.0                     2.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                   999.0               NaN                t               11
# 1                  1125.0               NaN                t                6
# 2                    31.0               NaN                t                5
# 3                   180.0               NaN                t               30
# 4                   330.0               NaN                t               30
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               32               53                65            2025-06-21
# 1               12               29               174            2025-06-23
# 2               12               31                39            2025-06-22
# 3               60               90               333            2025-06-22
# 4               60               90               365            2025-06-22
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 48                      6                       2
# 1                 88                     10                       1
# 2                147                     26                       0
# 3                 25                      9                       0
# 4                  3                      0                       0
#
#    availability_eoy  number_of_reviews_ly  estimated_occupancy_l365d  \
# 0                65                     5                         36
# 1               124                     7                         60
# 2                39                    37                        156
# 3               193                    17                        255
# 4               193                     1                          0
#
#    estimated_revenue_l365d first_review last_review  review_scores_rating  \
# 0                   8352.0   2013-05-27  2025-06-11                  4.30
# 1                  22920.0   2011-03-15  2025-05-31                  4.82
# 2                  29016.0   2011-07-17  2025-05-14                  4.46
# 3                  33405.0   2010-07-10  2024-11-05                  4.36
# 4                      0.0   2014-05-06  2024-02-19                  4.00
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.36                       4.53                   4.62
# 1                    4.94                       4.90                   4.94
# 2                    4.44                       4.38                   4.88
# 3                    4.45                       4.55                   4.68
# 4                    4.67                       4.00                   2.67
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.60                    4.81                 4.28
# 1                         4.99                    4.65                 4.68
# 2                         4.89                    4.89                 4.47
# 3                         4.68                    4.73                 4.23
# 4                         3.67                    5.00                 4.00
#
#        license instant_bookable  calculated_host_listings_count  \
# 0  HUTB-002062                t                              28
# 1   HUTB005057                f                               1
# 2  HUTB-001722                f                               3
# 3       Exempt                f                               3
# 4  HUTB-076700                f                             355
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           28
# 1                                            1
# 2                                            3
# 3                                            3
# 4                                          355
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.33
# 1                                            0               0.51
# 2                                            0               0.87
# 3                                            0               0.14
# 4                                            0               0.02

# %%
df.shape
# Out:
# (18927, 79)

# %% [markdown]
# # Sección 1:

# %% [markdown]
# ### Poner un análisis descriptivo de todas las variables (hacer un describe del dataframe "df.describe()")

# %%
### iMPORTAR DEPENDENCIAS ###
import pandas as pd
import numpy as np
import pyarrow
import fastparquet
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.graphics.gofplots import ProbPlot

# %%
    # ==========================
    # CONFIGURACIÓN
    # ==========================
    PATH = "listings.csv.gz"
    OUT_CSV = "listings_clean.csv"

    MISSING_COL_DROP_THRESHOLD = 0.60
    CRITICAL_COLS = ["id", "price", "latitude", "longitude"]
    GROUP_FOR_IMPUTE = "neighbourhood_cleansed"

    # ==========================
    # 1) CARGA
    # ==========================
    df = pd.read_csv(PATH, compression="gzip", low_memory=False)

    print("\n================ INICIO PROCESO =================")
    print("Shape inicial:", df.shape)
    print("\nPrimeras filas:")
    print(df.head(3))

    # ==========================
    # 2) DIAGNÓSTICO INICIAL
    # ==========================
    dup_rows = df.duplicated().sum()
    print(f"\nDuplicados completos detectados: {dup_rows}")

    if "id" in df.columns:
        dup_id = df.duplicated(subset=["id"]).sum()
        print(f"Duplicados por ID detectados: {dup_id}")

    missing_ratio = df.isna().mean()
    missing_count = df.isna().sum()

    # ==========================
    # 3) ELIMINAR COLUMNAS CON MUCHOS FALTANTES
    # ==========================
    cols_to_drop = missing_ratio[missing_ratio > MISSING_COL_DROP_THRESHOLD].index.tolist()

    if cols_to_drop:
        print("\nColumnas eliminadas por exceso de faltantes (>60%):")
        for col in cols_to_drop:
            print(f" - {col} | Faltantes: {missing_count[col]} ({round(missing_ratio[col]*100,2)}%)")
        df = df.drop(columns=cols_to_drop)
    else:
        print("\nNo se eliminaron columnas por faltantes.")

    # ==========================
    # 4) LIMPIEZA DE FORMATOS
    # ==========================
    print("\nCorrigiendo formatos...")

    date_cols = ["last_scraped", "calendar_last_scraped", "host_since",
                "first_review", "last_review"]

    for c in date_cols:
        if c in df.columns:
            before_na = df[c].isna().sum()
            df[c] = pd.to_datetime(df[c], errors="coerce")
            after_na = df[c].isna().sum()
            print(f" - Fecha convertida: {c} | Nuevos NaT generados: {after_na - before_na}")

    if "price" in df.columns:
        before_na = df["price"].isna().sum()
        df["price"] = (
            df["price"]
            .astype("string")
            .str.replace(r"[\$,]", "", regex=True)
            .str.strip()
            .replace({"": pd.NA})
        )
        df["price"] = pd.to_numeric(df["price"], errors="coerce")
        after_na = df["price"].isna().sum()
        print(f" - Price convertido a numérico | Nuevos NA: {after_na - before_na}")

    # ==========================
    # 5) ELIMINAR DUPLICADOS
    # ==========================
    before_dup = len(df)

    if "id" in df.columns:
        df = df.drop_duplicates(subset=["id"], keep="last")
    else:
        df = df.drop_duplicates()

    after_dup = len(df)
    print(f"\nFilas eliminadas por duplicados: {before_dup - after_dup}")

    # ==========================
    # 6) ELIMINAR FILAS CRÍTICAS
    # ==========================
    critical_existing = [c for c in CRITICAL_COLS if c in df.columns]

    if critical_existing:
        before_rows = len(df)
        df = df.dropna(subset=critical_existing)
        after_rows = len(df)

        print("\nFilas eliminadas por faltantes en columnas críticas:")
        print("Columnas críticas consideradas:", critical_existing)
        print("Filas eliminadas:", before_rows - after_rows)

    # ==========================
    # 7) IMPUTACIÓN CONTROLADA
    # ==========================
    print("\nIniciando imputación...")

    num_cols = df.select_dtypes(include=["number"]).columns
    cat_cols = df.select_dtypes(include=["object", "string"]).columns
    bool_cols = df.select_dtypes(include=["boolean"]).columns

    def report_impute(col, before, after):
        imputados = after - before
        if imputados > 0:
            print(f" - {col}: {imputados} valores imputados")

    # Numéricas
    for c in num_cols:
        before_na = df[c].isna().sum()
        med = df[c].median()
        df[c] = df[c].fillna(med)
        after_na = df[c].isna().sum()
        report_impute(c, after_na, before_na)

    # Categóricas
    for c in cat_cols:
        before_na = df[c].isna().sum()
        mode = df[c].mode()
        if len(mode) > 0:
            df[c] = df[c].fillna(mode[0])
        after_na = df[c].isna().sum()
        report_impute(c, after_na, before_na)

    # Booleanas
    for c in bool_cols:
        before_na = df[c].isna().sum()
        mode = df[c].mode()
        if len(mode) > 0:
            df[c] = df[c].fillna(mode[0])
        after_na = df[c].isna().sum()
        report_impute(c, after_na, before_na)

    # ==========================
    # 8) REPORTE FINAL
    # ==========================
    print("\n================ REPORTE FINAL =================")
    print("Shape final:", df.shape)

    remaining_na = df.isna().sum().sum()
    print("Total valores faltantes restantes:", remaining_na)

    if remaining_na == 0:
        print("Dataset completamente limpio 🎉")

    # ==========================
    # 9) GUARDAR
    # ==========================
    df.to_csv(OUT_CSV, index=False)
    print("\nArchivo guardado:", OUT_CSV)
    print("================ FIN DEL PROCESO =================")
# Out:
# ================ INICIO PROCESO =================
# Shape inicial: (18927, 79)
#
# Primeras filas:
#       id                         listing_url       scrape_id last_scraped  \
# 0  18674  https://www.airbnb.com/rooms/18674  20250612050654   2025-06-21
# 1  23197  https://www.airbnb.com/rooms/23197  20250612050654   2025-06-23
# 2  32711  https://www.airbnb.com/rooms/32711  20250612050654   2025-06-22
#
#         source                                               name  \
# 0  city scrape    Huge flat for 8 people close to Sagrada Familia
# 1  city scrape  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2  city scrape                   Sagrada Familia area - Còrsega 1
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Beautiful and Spacious Apartment with Large Te...
# 2  A lovely two bedroom apartment only 250 m from...
#
#                                neighborhood_overview  \
# 0  Apartment in Barcelona located in the heart of...
# 1  Strategically located in the Parc del Fòrum, a...
# 2  What's nearby  <br />This apartment is located...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/13031453/413c...    71615
# 1  https://a0.muscache.com/pictures/miso/Hosting-...    90417
# 2  https://a0.muscache.com/pictures/357b25e4-f414...   135703
#
#                                    host_url       host_name  host_since  \
# 0   https://www.airbnb.com/users/show/71615   Mireia  Maria  2010-01-19
# 1   https://www.airbnb.com/users/show/90417  Etain (Marnie)  2010-03-09
# 2  https://www.airbnb.com/users/show/135703            Nick  2010-05-31
#
#       host_location                                         host_about  \
# 0  Barcelona, Spain  We are Mireia (47) & Maria (49), two multiling...
# 1  Catalonia, Spain  Hi there,\n\nI’m marnie, originally from Austr...
# 2  Barcelona, Spain  I'm Nick your English host in Barcelona.\r\n\r...
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0     within an hour                96%                  91%
# 1     within an hour               100%                  96%
# 2     within an hour               100%                 100%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/pictures/user/User/...
# 1                 t  https://a0.muscache.com/im/pictures/user/44b56...
# 2                 f  https://a0.muscache.com/im/users/135703/profil...
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/pictures/user/User/...
# 1  https://a0.muscache.com/im/pictures/user/44b56...
# 2  https://a0.muscache.com/im/users/135703/profil...
#
#                 host_neighbourhood  host_listings_count  \
# 0               la Sagrada Família                 44.0
# 1            El Besòs i el Maresme                  6.0
# 2  Camp d'en Grassot i Gràcia Nova                  3.0
#
#    host_total_listings_count                host_verifications  \
# 0                       46.0                ['email', 'phone']
# 1                        9.0                ['email', 'phone']
# 2                       15.0  ['email', 'phone', 'work_email']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      t
#
#                            neighbourhood              neighbourhood_cleansed  \
# 0                   Barcelona, CT, Spain                  la Sagrada Família
# 1  Sant Adria de Besos, Barcelona, Spain               el Besòs i el Maresme
# 2            Barcelona, Catalonia, Spain  el Camp d'en Grassot i Gràcia Nova
#
#   neighbourhood_group_cleansed   latitude  longitude       property_type  \
# 0                     Eixample  41.405560    2.17262  Entire rental unit
# 1                   Sant Martí  41.412432    2.21975  Entire rental unit
# 2                       Gràcia  41.405660    2.17015  Entire rental unit
#
#          room_type  accommodates  bathrooms bathrooms_text  bedrooms  beds  \
# 0  Entire home/apt             8        2.0        2 baths       3.0   6.0
# 1  Entire home/apt             5        2.0        2 baths       3.0   4.0
# 2  Entire home/apt             6        1.5      1.5 baths       2.0   3.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["30 inch TV", "AC - split type ductless syste...  $232.00               1
# 1  ["Bed linens", "Ceiling fan", "Oven", "AC - sp...  $382.00               3
# 2  ["Oven", "AC - split type ductless system", "S...  $186.00               1
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                     1.0                     5.0
# 1              32                     2.0                     7.0
# 2              31                     1.0                     1.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                   999.0                   999.0                     2.2
# 1                  1125.0                  1125.0                     3.3
# 2                    31.0                    31.0                     1.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                   999.0               NaN                t               11
# 1                  1125.0               NaN                t                6
# 2                    31.0               NaN                t                5
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               32               53                65            2025-06-21
# 1               12               29               174            2025-06-23
# 2               12               31                39            2025-06-22
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 48                      6                       2
# 1                 88                     10                       1
# 2                147                     26                       0
#
#    availability_eoy  number_of_reviews_ly  estimated_occupancy_l365d  \
# 0                65                     5                         36
# 1               124                     7                         60
# 2                39                    37                        156
#
#    estimated_revenue_l365d first_review last_review  review_scores_rating  \
# 0                   8352.0   2013-05-27  2025-06-11                  4.30
# 1                  22920.0   2011-03-15  2025-05-31                  4.82
# 2                  29016.0   2011-07-17  2025-05-14                  4.46
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.36                       4.53                   4.62
# 1                    4.94                       4.90                   4.94
# 2                    4.44                       4.38                   4.88
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.60                    4.81                 4.28
# 1                         4.99                    4.65                 4.68
# 2                         4.89                    4.89                 4.47
#
#        license instant_bookable  calculated_host_listings_count  \
# 0  HUTB-002062                t                              28
# 1   HUTB005057                f                               1
# 2  HUTB-001722                f                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           28
# 1                                            1
# 2                                            3
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.33
# 1                                            0               0.51
# 2                                            0               0.87
#
# Duplicados completos detectados: 0
# Duplicados por ID detectados: 0
#
# Columnas eliminadas por exceso de faltantes (>60%):
#  - calendar_updated | Faltantes: 18927 (100.0%)
#
# Corrigiendo formatos...
#  - Fecha convertida: last_scraped | Nuevos NaT generados: 0
#  - Fecha convertida: calendar_last_scraped | Nuevos NaT generados: 0
#  - Fecha convertida: host_since | Nuevos NaT generados: 0
#  - Fecha convertida: first_review | Nuevos NaT generados: 0
#  - Fecha convertida: last_review | Nuevos NaT generados: 0
#  - Price convertido a numérico | Nuevos NA: 0
#
# Filas eliminadas por duplicados: 0
#
# Filas eliminadas por faltantes en columnas críticas:
# Columnas críticas consideradas: ['id', 'price', 'latitude', 'longitude']
# Filas eliminadas: 4014
#
# Iniciando imputación...
#  - host_listings_count: 1 valores imputados
#  - host_total_listings_count: 1 valores imputados
#  - bathrooms: 4 valores imputados
#  - bedrooms: 17 valores imputados
#  - beds: 72 valores imputados
#  - minimum_minimum_nights: 4 valores imputados
#  - maximum_minimum_nights: 4 valores imputados
#  - minimum_maximum_nights: 4 valores imputados
#  - maximum_maximum_nights: 4 valores imputados
#  - review_scores_rating: 3511 valores imputados
#  - review_scores_accuracy: 3512 valores imputados
#  - review_scores_cleanliness: 3512 valores imputados
#  - review_scores_checkin: 3512 valores imputados
#  - review_scores_communication: 3511 valores imputados
#  - review_scores_location: 3511 valores imputados
#  - review_scores_value: 3511 valores imputados
#  - reviews_per_month: 3511 valores imputados
#  - description: 538 valores imputados
#  - neighborhood_overview: 7578 valores imputados
#  - host_name: 1 valores imputados
#  - host_location: 3047 valores imputados
#  - host_about: 4930 valores imputados
#  - host_response_time: 715 valores imputados
#  - host_response_rate: 715 valores imputados
#  - host_acceptance_rate: 666 valores imputados
#  - host_is_superhost: 502 valores imputados
#  - host_thumbnail_url: 1 valores imputados
#  - host_picture_url: 1 valores imputados
#  - host_neighbourhood: 7518 valores imputados
#  - host_verifications: 1 valores imputados
#  - host_has_profile_pic: 1 valores imputados
#  - host_identity_verified: 1 valores imputados
#  - neighbourhood: 7578 valores imputados
#  - bathrooms_text: 6 valores imputados
#  - has_availability: 156 valores imputados
#  - license: 4305 valores imputados
#
# ================ REPORTE FINAL =================
# Shape final: (14913, 78)
# Total valores faltantes restantes: 7023
#
# Archivo guardado: listings_clean.csv
# ================ FIN DEL PROCESO =================

# %%
# Verificacion de que no hayan negativos 

# ==========================
# CHEQUEO: ¿HAY NÚMEROS NEGATIVOS?
# ==========================
num_cols = df.select_dtypes(include=["number"]).columns

neg_counts = (df[num_cols] < 0).sum().sort_values(ascending=False)
neg_counts = neg_counts[neg_counts > 0]

if len(neg_counts) == 0:
    print("\n✅ No hay números negativos en ninguna columna numérica.")
else:
    print("\n⚠️ Columnas con valores negativos:")
    for col, cnt in neg_counts.items():
        min_val = df[col].min()
        print(f" - {col}: {cnt} negativos | mínimo = {min_val}")

    # (Opcional) ver ejemplos de filas con negativos (máx 10)
    cols_with_neg = neg_counts.index.tolist()
    mask_neg = (df[cols_with_neg] < 0).any(axis=1)
    print("\nEjemplos de filas con negativos:")
    print(df.loc[mask_neg, ["id"] + cols_with_neg].head(10))
# Out:
# ✅ No hay números negativos en ninguna columna numérica.

# %% [markdown]
# # Sección 2:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurar que price sea numérico
df["price"] = pd.to_numeric(df["price"], errors="coerce")

# Lista de columnas numéricas relevantes
cols = [
    "price",
    "bedrooms",
    "bathrooms",
    "accommodates",
    "number_of_reviews",
    "review_scores_rating",
    "availability_365",
    "estimated_revenue_l365d",
    "reviews_per_month"
]

# Quedarse solo con las que realmente existan en el dataset
cols_exist = [c for c in cols if c in df.columns]

# Crear df solo con esas columnas y convertir a numérico por seguridad
df_num = df[cols_exist].apply(pd.to_numeric, errors="coerce")

print("Columnas usadas:", cols_exist)
print("Shape df_num:", df_num.shape)
# Out:
# Columnas usadas: ['price', 'bedrooms', 'bathrooms', 'accommodates', 'number_of_reviews', 'review_scores_rating', 'availability_365', 'estimated_revenue_l365d', 'reviews_per_month']
# Shape df_num: (14913, 9)

# %% [markdown]
# # Histogramas (Distribución Individual)

# %%
df_num.hist(figsize=(14,10), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Boxplot de price (Usado para detectar outliers)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["price"])
plt.title("Distribución del precio")
plt.show()

## otra manera de ver outliers es con percentiles
q1 = df["price"].quantile(0.25)
q3 = df["price"].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
print(f"Rango sin outliers: [{lower_bound:.2f}, {upper_bound:.2f}]")
outliers = df[(df["price"] < lower_bound) | (df["price"] > upper_bound)]
print(f"Cantidad de outliers: {len(outliers)}")

## otra manera es la siguiente##

plt.figure(figsize=(6,4))
sns.boxplot(x=df["price"])
plt.xlim(0, 500)  # ajustar según tu ciudad
plt.show()
# Out:
# Rango sin outliers: [-199.00, 529.00]
# Cantidad de outliers: 661

# %% [markdown]
# # Relación entre variables (Scatterplots)

# %% [markdown]
# ## Precio vs Habitaciones

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="bedrooms", y="price", data=df)
plt.title("Precio vs Bedrooms")
plt.show()

# %% [markdown]
# ## Precio vs Capacidad

# %%
sns.scatterplot(x="accommodates", y="price", data=df)
plt.show()

# %% [markdown]
# ## Precio vs Rating

# %%
sns.scatterplot(x="review_scores_rating", y="price", data=df)
plt.show()

# %% [markdown]
# # Matriz de correlación

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_num.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# # Distribución geográfica (Usando Latitud y Longitud)

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["longitude"], df["latitude"], 
            c=df["price"], cmap="viridis", alpha=0.5)

plt.colorbar(label="Price")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Mapa de precios")
plt.show()

# %% [markdown]
# ##### Poner mapa

# %% [markdown]
# # Sección 3:

# %%
## ==========================
# IMPUTACIÓN CORREGIDA PARA AIRBNB
# ==========================

print("\n================ IMPUTACIÓN CORREGIDA =================")

# --------------------------
# 1) NO TOCAR COORDENADAS
# --------------------------
# latitude y longitude pueden ser negativos según el país
# no se imputan, si faltan ya se eliminaron en críticas

COORD_COLS = ["latitude", "longitude"]

# --------------------------
# 2) MNAR REAL (RESEÑAS)
# --------------------------
review_score_cols = [c for c in df.columns if c.startswith("review_scores_")]
review_like_cols = ["reviews_per_month"]
mnar_cols = review_score_cols + [c for c in review_like_cols if c in df.columns]

if mnar_cols:
    print("\n🔴 MNAR estructural (sin reviews = 0 + flag)")
    for c in mnar_cols:
        missing_before = df[c].isna().sum()
        if missing_before > 0:
            df[f"{c}__was_missing"] = df[c].isna().astype(int)
            df[c] = df[c].fillna(0)
            print(f" - {c}: {missing_before} -> 0 + flag")

# --------------------------
# 3) VARIABLES QUE DEBEN SER >= 0
# --------------------------
non_negative_cols = [
    "price", "minimum_nights", "maximum_nights",
    "availability_30", "availability_60", "availability_90",
    "availability_365", "number_of_reviews",
    "number_of_reviews_ltm", "number_of_reviews_l30d",
    "beds", "bedrooms", "bathrooms",
    "accommodates",
    "estimated_occupancy_l365d",
    "estimated_revenue_l365d"
]

non_negative_cols = [c for c in non_negative_cols if c in df.columns]

# Convertir negativos inválidos en NaN
for c in non_negative_cols:
    neg_count = (df[c] < 0).sum()
    if neg_count > 0:
        df.loc[df[c] < 0, c] = pd.NA
        print(f"🛠 {c}: {neg_count} negativos convertidos a NA")

# --------------------------
# 4) IMPUTACIÓN NUMÉRICA INTELIGENTE
# --------------------------
GROUP_COL = "neighbourhood_cleansed"
use_group = GROUP_COL in df.columns

num_cols = df.select_dtypes(include=["number"]).columns.tolist()

# excluir:
num_cols = [
    c for c in num_cols
    if c not in mnar_cols
    and c not in COORD_COLS
]

print("\n🟢 Imputando numéricas...")

if use_group:
    print(f" - Mediana por grupo ({GROUP_COL}) con fallback global")
    global_medians = df[num_cols].median(numeric_only=True)

    for c in num_cols:
        miss_before = df[c].isna().sum()
        if miss_before == 0:
            continue

        df[c] = df.groupby(GROUP_COL)[c].transform(
            lambda s: s.fillna(s.median())
        )

        df[c] = df[c].fillna(global_medians.get(c, df[c].median()))

        miss_after = df[c].isna().sum()
        print(f"   * {c}: imputados {miss_before - miss_after}")

else:
    print(" - Mediana global")
    for c in num_cols:
        miss_before = df[c].isna().sum()
        if miss_before == 0:
            continue

        df[c] = df[c].fillna(df[c].median())
        miss_after = df[c].isna().sum()
        print(f"   * {c}: imputados {miss_before - miss_after}")

# --------------------------
# 5) CLIP FINAL (SEGURIDAD)
# --------------------------
for c in non_negative_cols:
    df[c] = df[c].clip(lower=0)

# --------------------------
# 6) CATEGÓRICAS
# --------------------------
cat_cols = df.select_dtypes(include=["object", "string", "category"]).columns

# no tocar ID ni URLs
cat_exclude = ["id", "listing_url", "host_url", "picture_url"]
cat_cols = [c for c in cat_cols if c not in cat_exclude]

print('\n🟡 Imputando categóricas con "Unknown"...')

for c in cat_cols:
    miss_before = df[c].isna().sum()
    if miss_before == 0:
        continue

    df[c] = df[c].fillna("Unknown")
    miss_after = df[c].isna().sum()

    print(f"   * {c}: imputados {miss_before - miss_after}")

print("\n================ FIN IMPUTACIÓN =================")
# Out:
# ================ IMPUTACIÓN CORREGIDA =================
#
# 🔴 MNAR estructural (sin reviews = 0 + flag)
#
# 🟢 Imputando numéricas...
#  - Mediana por grupo (neighbourhood_cleansed) con fallback global
#
# 🟡 Imputando categóricas con "Unknown"...
#
# ================ FIN IMPUTACIÓN =================

# %% [markdown]
# # Sección 4:

# %% [markdown]
# # Visualizar outliers con boxplots

# %%
variables = ["price", "bedrooms", "accommodates"]

for var in variables:
    plt.figure()
    df.boxplot(column=var)
    plt.title(f"Boxplot de {var}")
    plt.show()

# %% [markdown]
# # Detectar outliers con método IQR

# %%
def detectar_outliers_iqr(data, columna):
    Q1 = data[columna].quantile(0.25)
    Q3 = data[columna].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    outliers = data[(data[columna] < lower) | (data[columna] > upper)]
    
    print(f"\n🔎 {columna}")
    print("Lower bound:", lower)
    print("Upper bound:", upper)
    print("Cantidad outliers:", len(outliers))
    
    return lower, upper

bounds = {}
for var in variables:
    bounds[var] = detectar_outliers_iqr(df, var)
# Out:
# 🔎 price
# Lower bound: -199.0
# Upper bound: 529.0
# Cantidad outliers: 661
#
# 🔎 bedrooms
# Lower bound: -0.5
# Upper bound: 3.5
# Cantidad outliers: 1160
#
# 🔎 accommodates
# Lower bound: -2.5
# Upper bound: 9.5
# Cantidad outliers: 377

# %% [markdown]
# # Analisis Price

# %%
# Limpiar price
df["price"] = (
    df["price"]
    .astype(str)
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
)

# Capping al percentil 99
p99_price = df["price"].quantile(0.99)
df["price"] = df["price"].clip(upper=p99_price)

# Transformación log
df["price_log"] = np.log1p(df["price"])

# %% [markdown]
# ##### Reduce heterocedasticidad
#
# ##### Mejora convergencia del modelo
#
# ##### Hace la distribución más cercana a normal
#
# ##### Reduce sensibilidad a outliers extremos

# %% [markdown]
# # BEDROOMS

# %%
p99_bed = df["bedrooms"].quantile(0.99)
df["bedrooms"] = df["bedrooms"].clip(upper=p99_bed)

# %% [markdown]
# # ACCOMMODATES

# %%
p95_acc = df["accommodates"].quantile(0.95)
df["accommodates"] = df["accommodates"].clip(upper=p95_acc)

# %% [markdown]
# # Verificación Post-Tratamiento

# %%
for var in ["price_log", "bedrooms", "accommodates"]:
    plt.figure()
    df.boxplot(column=var)
    plt.title(f"Boxplot post-tratamiento: {var}")
    plt.show()

# %% [markdown]
# # Mirar como estan los datos

# %%
# ==========================
# EXPORTAR DF HASTA PUNTO 4
# ==========================

# (Opcional) Recomendado: guardar también las versiones "capped" con nombres claros
if "price_capped" not in df.columns and "price" in df.columns:
    df["price_capped"] = df["price"]  # por si ya lo capeaste directo sobre price

if "bedrooms_capped" not in df.columns and "bedrooms" in df.columns:
    df["bedrooms_capped"] = df["bedrooms"]

if "accommodates_capped" not in df.columns and "accommodates" in df.columns:
    df["accommodates_capped"] = df["accommodates"]

# Archivo de salida
OUT_CSV_P4 = "listings_hasta_punto_4.csv"

# Exportar
df.to_csv(OUT_CSV_P4, index=False, encoding="utf-8-sig")

print("✅ Exportado:", OUT_CSV_P4)
print("Shape exportado:", df.shape)
print("Columnas clave incluidas:",
      [c for c in ["price", "price_capped", "price_log", "bedrooms", "bedrooms_capped", "accommodates", "accommodates_capped"] if c in df.columns])
# Out:
# ✅ Exportado: listings_hasta_punto_4.csv
# Shape exportado: (14913, 82)
# Columnas clave incluidas: ['price', 'price_capped', 'price_log', 'bedrooms', 'bedrooms_capped', 'accommodates', 'accommodates_capped']

# %% [markdown]
# # Sección 5:

# %% [markdown]
# # En base al precio de los AirBNB

# %% [markdown]
# # Entrenamiento – Regresión Lineal

# %% [markdown]
# # Conocer todas las variables numericas

# %%
num_features = df.select_dtypes(include=["number"]).columns.tolist()
print("Características numéricas disponibles para modelado:", num_features)
# Out:
# Características numéricas disponibles para modelado: ['id', 'scrape_id', 'host_id', 'host_listings_count', 'host_total_listings_count', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy', 'number_of_reviews_ly', 'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month', 'price_log', 'price_capped', 'bedrooms_capped', 'accommodates_capped']

# %% [markdown]
# # Crear el arreglo

# %%
num_features = [
    # Host
    "host_response_rate",
    "host_acceptance_rate",
    "host_listings_count",
    "host_total_listings_count",
    "calculated_host_listings_count",
    "calculated_host_listings_count_entire_homes",
    "calculated_host_listings_count_private_rooms",
    "calculated_host_listings_count_shared_rooms",

    # Ubicación
    "latitude",
    "longitude",

    # Propiedad
    "accommodates",
    "accommodates_capped",
    "bathrooms",
    "bedrooms",
    "bedrooms_capped",
    "beds",

    # Noches
    "minimum_nights",
    "maximum_nights",
    "minimum_minimum_nights",
    "maximum_minimum_nights",
    "minimum_maximum_nights",
    "maximum_maximum_nights",
    "minimum_nights_avg_ntm",
    "maximum_nights_avg_ntm",

    # Disponibilidad
    "availability_30",
    "availability_60",
    "availability_90",
    "availability_365",
    "availability_eoy",

    # Reviews
    "number_of_reviews",
    "number_of_reviews_ltm",
    "number_of_reviews_l30d",
    "number_of_reviews_ly",
    "reviews_per_month",

    # Ocupación
    "estimated_occupancy_l365d",

    # Scores
    "review_scores_rating",
    "review_scores_accuracy",
    "review_scores_cleanliness",
    "review_scores_checkin",
    "review_scores_communication",
    "review_scores_location",
    "review_scores_value"
]

# %% [markdown]
# # Modelo de regresion

# %%
# ==========================
# REGRESIÓN LINEAL DEFINITIVA
# ==========================

# 1️⃣ Variable objetivo
y = pd.to_numeric(df["price_log"], errors="coerce")

# 2️⃣ Asegurar que solo use variables que realmente existen en el df
num_features_existing = [c for c in num_features if c in df.columns]

print("Variables usadas:", len(num_features_existing))
print(num_features_existing)

# 3️⃣ Construcción de X
X = df[num_features_existing].copy()

# convertir todo a numérico
X = X.apply(pd.to_numeric, errors="coerce")

# 4️⃣ Limpiar inf y NA (solo para el modelo)
data = (
    pd.concat([X, y.rename("price_log")], axis=1)
    .replace([np.inf, -np.inf], np.nan)
    .dropna()
)

X_clean = data.drop(columns=["price_log"]).astype("float64")
y_clean = data["price_log"].astype("float64")

print("Filas usadas para entrenar:", len(y_clean))

# 5️⃣ Modelo OLS
X_sm = sm.add_constant(X_clean, has_constant="add").astype("float64")
modelo = sm.OLS(y_clean, X_sm).fit()

# Forzar tipos numéricos válidos para statsmodels (evita dtype=object)
X_sm = sm.add_constant(X_clean, has_constant="add").astype(float)
y_clean = pd.to_numeric(y_clean, errors="coerce").astype(float)

# Alinear y limpiar por si quedó algún NaN
mask = y_clean.notna() & X_sm.notna().all(axis=1)
X_sm = X_sm.loc[mask]
y_clean = y_clean.loc[mask]

modelo = sm.OLS(y_clean, X_sm).fit()

# 6️⃣ Métricas adicionales
y_pred = modelo.predict(X_sm)

rmse = np.sqrt(mean_squared_error(y_clean, y_pred))
mae = mean_absolute_error(y_clean, y_pred)

print("\n================ MÉTRICAS =================")
print("R²:", modelo.rsquared)
print("R² Ajustado:", modelo.rsquared_adj)
print("RMSE:", rmse)
print("MAE:", mae)

print(modelo.summary())
# Out:
# Variables usadas: 42
# ['host_response_rate', 'host_acceptance_rate', 'host_listings_count', 'host_total_listings_count', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'latitude', 'longitude', 'accommodates', 'accommodates_capped', 'bathrooms', 'bedrooms', 'bedrooms_capped', 'beds', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'availability_eoy', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'number_of_reviews_ly', 'reviews_per_month', 'estimated_occupancy_l365d', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']
# Filas usadas para entrenar: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 34
#      32 # 5️⃣ Modelo OLS
#      33 X_sm = sm.add_constant(X_clean, has_constant="add").astype("float64")
# ---> 34 modelo = sm.OLS(y_clean, X_sm).fit()
#      36 # Forzar tipos numéricos válidos para statsmodels (evita dtype=object)
#      37 X_sm = sm.add_constant(X_clean, has_constant="add").astype(float)
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
#     922                           hasconst=hasconst, **kwargs)
#     923 if "weights" in self._init_keys:
#     924     self._init_keys.remove("weights")
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:746, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     744 else:
#     745     weights = weights.squeeze()
# --> 746 super().__init__(endog, exog, missing=missing,
#     747                           weights=weights, hasconst=hasconst, **kwargs)
#     748 nobs = self.exog.shape[0]
#     749 weights = self.weights
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:200, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     199 def __init__(self, endog, exog, **kwargs):
# --> 200     super().__init__(endog, exog, **kwargs)
#     201     self.pinv_wexog: Float64Array | None = None
#     202     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/data.py:694, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     691     exog = np.asarray(exog)
#     693 klass = handle_data_class_factory(endog, exog)
# --> 694 return klass(endog, exog=exog, missing=missing, hasconst=hasconst, **kwargs)
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/data.py:90, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      88 self.const_idx = None
#      89 self.k_constant = 0
# ---> 90 self._handle_constant(hasconst)
#      91 self._check_integrity()
#      92 self._cache = {}
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/data.py:137, in ModelData._handle_constant(self, hasconst)
#     134 else:
#     135     # detect where the constant is
#     136     check_implicit = False
# --> 137     exog_max = np.max(self.exog, axis=0)
#     138     if not np.isfinite(exog_max).all():
#     139         raise MissingDataError("exog contains inf or nans")
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3123, in max(a, axis, out, keepdims, initial, where)
#    3011 @array_function_dispatch(_max_dispatcher)
#    3012 @set_module('numpy')
#    3013 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3014          where=np._NoValue):
#    3015     """
#    3016     Return the maximum of an array or maximum along an axis.
#    3017
#    (...)   3121     5
#    3122     """
# -> 3123     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    3124                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:83, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      80         else:
#      81             return reduction(axis=axis, out=out, **passkwargs)
# ---> 83 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
def diagnostic_plots(X, y, model_fit=None, top_n=3):
    """
    4 diagnostic plots like R's plot(lm):
      1) Residuals vs Fitted
      2) Normal Q-Q
      3) Scale-Location
      4) Residuals vs Leverage (Cook's distance)

    X: DataFrame/array of predictors (NO constant column needed)
    y: Series/array target
    model_fit: fitted statsmodels OLS results (optional)
    top_n: number of points to label in each plot
    """

    # --- asegurar formatos y alineación ---
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)
    if isinstance(y, (np.ndarray, list)):
        y = pd.Series(y)

    X = X.copy()
    y = y.copy()

    # alinear índices (clave para anotaciones)
    data = pd.concat([X, y.rename("y")], axis=1).replace([np.inf, -np.inf], np.nan).dropna()
    X = data.drop(columns=["y"])
    y = data["y"]

    # fit si no lo pasan
    if model_fit is None:
        model_fit = sm.OLS(y, sm.add_constant(X)).fit()

    infl = model_fit.get_influence()

    fitted = model_fit.fittedvalues
    resid = model_fit.resid
    stud_resid = infl.resid_studentized_internal
    leverage = infl.hat_matrix_diag
    cooks = infl.cooks_distance[0]
    sqrt_abs_stud = np.sqrt(np.abs(stud_resid))

    # --------- 1) Residuals vs Fitted ----------
    fig1, ax1 = plt.subplots(figsize=(7,5))
    sns.residplot(x=fitted, y=resid, lowess=True,
                  scatter_kws={"alpha":0.5},
                  line_kws={"lw":1, "alpha":0.8},
                  ax=ax1)
    ax1.set_title("Residuals vs Fitted")
    ax1.set_xlabel("Fitted values")
    ax1.set_ylabel("Residuals")

    # anotar top_n por |residual|
    idx_top = np.argsort(np.abs(resid))[-top_n:]
    for i in idx_top:
        ax1.annotate(str(data.index[i]), (fitted.iloc[i], resid.iloc[i]))

    # --------- 2) Normal Q-Q ----------
    fig2 = plt.figure(figsize=(7,5))
    ax2 = fig2.add_subplot(111)
    QQ = ProbPlot(stud_resid)
    QQ.qqplot(line="45", alpha=0.5, ax=ax2)
    ax2.set_title("Normal Q-Q")
    ax2.set_xlabel("Theoretical Quantiles")
    ax2.set_ylabel("Standardized Residuals")

    idx_top = np.argsort(np.abs(stud_resid))[-top_n:]
    # coordenadas para anotar en el Q-Q
    theoretical = QQ.theoretical_quantiles
    ordered = np.sort(stud_resid)
    for j, i in enumerate(idx_top):
        # buscar posición aproximada del punto i dentro de la serie ordenada
        # (esto es una aproximación, suficiente para anotación visual)
        pos = np.searchsorted(ordered, stud_resid[i])
        pos = np.clip(pos, 0, len(theoretical)-1)
        ax2.annotate(str(data.index[i]), (theoretical[pos], stud_resid[i]))

    # --------- 3) Scale-Location ----------
    fig3, ax3 = plt.subplots(figsize=(7,5))
    ax3.scatter(fitted, sqrt_abs_stud, alpha=0.5)
    sns.regplot(x=fitted, y=sqrt_abs_stud, scatter=False, ci=False, lowess=True,
                line_kws={"lw":1, "alpha":0.8}, ax=ax3)
    ax3.set_title("Scale-Location")
    ax3.set_xlabel("Fitted values")
    ax3.set_ylabel(r"$\sqrt{|Standardized Residuals|}$")

    idx_top = np.argsort(sqrt_abs_stud)[-top_n:]
    for i in idx_top:
        ax3.annotate(str(data.index[i]), (fitted.iloc[i], sqrt_abs_stud[i]))

    # --------- 4) Residuals vs Leverage ----------
    fig4, ax4 = plt.subplots(figsize=(7,5))
    ax4.scatter(leverage, stud_resid, alpha=0.5)
    sns.regplot(x=leverage, y=stud_resid, scatter=False, ci=False, lowess=True,
                line_kws={"lw":1, "alpha":0.8}, ax=ax4)
    ax4.set_title("Residuals vs Leverage")
    ax4.set_xlabel("Leverage")
    ax4.set_ylabel("Standardized Residuals")
    ax4.set_xlim(0, leverage.max() + 0.01)

    # anotar top_n por Cook's distance
    idx_top = np.argsort(cooks)[-top_n:]
    for i in idx_top:
        ax4.annotate(str(data.index[i]), (leverage[i], stud_resid[i]))

    # líneas de Cook (0.5 y 1)
    p = int(model_fit.df_model) + 1  # params aprox (incluye intercepto)
    lev_space = np.linspace(0.001, leverage.max(), 100)
    cook_05 = np.sqrt((0.5 * p * (1 - lev_space)) / lev_space)
    cook_1 = np.sqrt((1.0 * p * (1 - lev_space)) / lev_space)

    ax4.plot(lev_space, cook_05, ls="--")
    ax4.plot(lev_space, -cook_05, ls="--")
    ax4.plot(lev_space, cook_1, ls=":")
    ax4.plot(lev_space, -cook_1, ls=":")

    plt.show()

    return model_fit

# %%
diagnostic_plots(X_clean, y_clean, model_fit=modelo)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Usar tus variables del modelo (NO el objeto modelo)
X_vif = X_clean.copy()

# Agregar constante
X_vif = sm.add_constant(X_vif)

vif_data = pd.DataFrame()
vif_data["Variable"] = X_vif.columns
vif_data["VIF"] = [
    variance_inflation_factor(X_vif.values, i)
    for i in range(X_vif.shape[1])
]

# Quitar la constante del análisis final
vif_data = vif_data[vif_data["Variable"] != "const"]

print("\n================ VIF =================")
print(vif_data.sort_values("VIF", ascending=False))
# Out:
# /home/lemarsito/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# ================ VIF =================
#                                         Variable           VIF
# 12                           accommodates_capped           inf
# 11                                  accommodates           inf
# 15                               bedrooms_capped           inf
# 14                                      bedrooms           inf
# 24                        maximum_nights_avg_ntm  1.038461e+11
# 21                        minimum_maximum_nights  4.408422e+10
# 22                        maximum_maximum_nights  2.973537e+10
# 5                 calculated_host_listings_count  7.132668e+04
# 6    calculated_host_listings_count_entire_homes  6.009565e+04
# 7   calculated_host_listings_count_private_rooms  1.613626e+04
# 26                               availability_60  2.747502e+01
# 27                               availability_90  2.353502e+01
# 3                            host_listings_count  2.186805e+01
# 31                         number_of_reviews_ltm  1.847273e+01
# 4                      host_total_listings_count  1.389164e+01
# 33                          number_of_reviews_ly  1.165664e+01
# 36                          review_scores_rating  7.209102e+00
# 29                              availability_eoy  6.779496e+00
# 25                               availability_30  6.731062e+00
# 23                        minimum_nights_avg_ntm  4.575578e+00
# 37                        review_scores_accuracy  4.471451e+00
# 20                        maximum_minimum_nights  4.431299e+00
# 42                           review_scores_value  4.239881e+00
# 34                             reviews_per_month  3.997273e+00
# 32                        number_of_reviews_l30d  3.809624e+00
# 40                   review_scores_communication  3.092635e+00
# 28                              availability_365  2.899084e+00
# 30                             number_of_reviews  2.840370e+00
# 8    calculated_host_listings_count_shared_rooms  2.813338e+00
# 38                     review_scores_cleanliness  2.797610e+00
# 19                        minimum_minimum_nights  2.575885e+00
# 39                         review_scores_checkin  2.447387e+00
# 17                                minimum_nights  2.210199e+00
# 35                     estimated_occupancy_l365d  2.147968e+00
# 16                                          beds  2.093748e+00
# 2                           host_acceptance_rate  1.732605e+00
# 41                        review_scores_location  1.696823e+00
# 13                                     bathrooms  1.528670e+00
# 1                             host_response_rate  1.443610e+00
# 18                                maximum_nights  1.202251e+00
# 10                                     longitude  1.104512e+00
# 9                                       latitude  1.091804e+00

# %%
num_features_Fix = [
        # Host
    "host_response_rate",
    "host_acceptance_rate",
    "host_listings_count",
    "host_total_listings_count",
    "calculated_host_listings_count",

    # Propiedad
    "accommodates_capped",
    "bathrooms",
    "bedrooms_capped",
    "beds",

    # Noches
    "minimum_nights",
    "maximum_nights",
    "minimum_minimum_nights",
    "maximum_minimum_nights",
    "minimum_maximum_nights",
    "maximum_maximum_nights",
    "minimum_nights_avg_ntm",
    "maximum_nights_avg_ntm",

    # Disponibilidad
    "availability_365",

    # Reviews
    "number_of_reviews",
    "reviews_per_month",

    # Ocupación
    "estimated_occupancy_l365d",

    # Scores
    "review_scores_rating",
    "review_scores_accuracy",
    "review_scores_cleanliness",
    "review_scores_checkin",
    "review_scores_communication",
    "review_scores_location",
    "review_scores_value"
]

# %%
# ==========================
# REGRESIÓN LINEAL DEFINITIVA
# ==========================

# 1️⃣ Variable objetivo
y = pd.to_numeric(df["price_log"], errors="coerce")

# 2️⃣ Asegurar que solo use variables que realmente existen en el df
num_features_existing = [c for c in num_features_Fix if c in df.columns]

print("Variables usadas:", len(num_features_existing))
print(num_features_existing)

# 3️⃣ Construcción de X
X = df[num_features_existing].copy()

# convertir todo a numérico
X = X.apply(pd.to_numeric, errors="coerce")

# 4️⃣ Limpiar inf y NA (solo para el modelo)
data = (
    pd.concat([X, y.rename("price_log")], axis=1)
    .replace([np.inf, -np.inf], np.nan)
    .dropna()
)

X_clean = data.drop(columns=["price_log"]).astype("float64")
y_clean = data["price_log"].astype("float64")

print("Filas usadas para entrenar:", len(y_clean))

# 5️⃣ Modelo OLS
X_sm = sm.add_constant(X_clean, has_constant="add").astype("float64")
modelo = sm.OLS(y_clean, X_sm).fit()

# Forzar tipos numéricos válidos para statsmodels (evita dtype=object)
X_sm = sm.add_constant(X_clean, has_constant="add").astype(float)
y_clean = pd.to_numeric(y_clean, errors="coerce").astype(float)

# Alinear y limpiar por si quedó algún NaN
mask = y_clean.notna() & X_sm.notna().all(axis=1)
X_sm = X_sm.loc[mask]
y_clean = y_clean.loc[mask]

modelo = sm.OLS(y_clean, X_sm).fit()

# 6️⃣ Métricas adicionales
y_pred = modelo.predict(X_sm)

rmse = np.sqrt(mean_squared_error(y_clean, y_pred))
mae = mean_absolute_error(y_clean, y_pred)

print("\n================ MÉTRICAS =================")
print("R²:", modelo.rsquared)
print("R² Ajustado:", modelo.rsquared_adj)
print("RMSE:", rmse)
print("MAE:", mae)

print(modelo.summary())
# Out:
# Variables usadas: 28
# ['host_response_rate', 'host_acceptance_rate', 'host_listings_count', 'host_total_listings_count', 'calculated_host_listings_count', 'accommodates_capped', 'bathrooms', 'bedrooms_capped', 'beds', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_365', 'number_of_reviews', 'reviews_per_month', 'estimated_occupancy_l365d', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']
# Filas usadas para entrenar: 14913
#
# ================ MÉTRICAS =================
# R²: 0.6131095386191001
# R² Ajustado: 0.612381714585328
# RMSE: 0.5311922828120974
# MAE: 0.40193126816442654
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              price_log   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     842.4
# Date:                Wed, 25 Feb 2026   Prob (F-statistic):               0.00
# Time:                        08:44:00   Log-Likelihood:                -11726.
# No. Observations:               14913   AIC:                         2.351e+04
# Df Residuals:                   14884   BIC:                         2.373e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              2.8808      0.081     35.609      0.000       2.722       3.039
# host_response_rate                 0.0266      0.031      0.849      0.396      -0.035       0.088
# host_acceptance_rate               0.3768      0.023     16.207      0.000       0.331       0.422
# host_listings_count               -0.0005      0.000     -5.178      0.000      -0.001      -0.000
# host_total_listings_count          0.0004    7.5e-05      4.854      0.000       0.000       0.001
# calculated_host_listings_count     0.0006      0.000      5.359      0.000       0.000       0.001
# accommodates_capped                0.2440      0.004     64.710      0.000       0.237       0.251
# bathrooms                          0.0566      0.006      9.017      0.000       0.044       0.069
# bedrooms_capped                   -0.0334      0.007     -4.964      0.000      -0.047      -0.020
# beds                               0.0032      0.003      1.176      0.239      -0.002       0.009
# minimum_nights                    -0.0010      0.000     -3.577      0.000      -0.002      -0.000
# maximum_nights                  1.511e-05   1.23e-05      1.229      0.219   -8.98e-06    3.92e-05
# minimum_minimum_nights            -0.0159      0.000    -41.529      0.000      -0.017      -0.015
# maximum_minimum_nights             0.0011      0.000      7.108      0.000       0.001       0.001
# minimum_maximum_nights            -0.0002   3.67e-05     -4.269      0.000      -0.000   -8.48e-05
# maximum_maximum_nights         -3.282e-05      3e-05     -1.093      0.274   -9.16e-05     2.6e-05
# minimum_nights_avg_ntm            -0.0015      0.000     -6.940      0.000      -0.002      -0.001
# maximum_nights_avg_ntm             0.0002   5.63e-05      3.368      0.001    7.92e-05       0.000
# availability_365                   0.0005   4.19e-05     11.914      0.000       0.000       0.001
# number_of_reviews                  0.0005   5.27e-05      8.587      0.000       0.000       0.001
# reviews_per_month                 -0.0041      0.003     -1.445      0.148      -0.010       0.001
# estimated_occupancy_l365d         -0.0009   5.74e-05    -14.847      0.000      -0.001      -0.001
# review_scores_rating               0.0727      0.028      2.553      0.011       0.017       0.129
# review_scores_accuracy             0.0370      0.023      1.597      0.110      -0.008       0.082
# review_scores_cleanliness          0.2279      0.018     12.556      0.000       0.192       0.264
# review_scores_checkin             -0.0350      0.018     -1.962      0.050      -0.070   -3.57e-05
# review_scores_communication       -0.0552      0.019     -2.861      0.004      -0.093      -0.017
# review_scores_location             0.0733      0.018      4.015      0.000       0.038       0.109
# review_scores_value               -0.1162      0.020     -5.937      0.000      -0.154      -0.078
# ==============================================================================
# Omnibus:                     2485.080   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22177.172
# Skew:                           0.538   Prob(JB):                         0.00
# Kurtosis:                       8.876   Cond. No.                     8.12e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.12e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
diagnostic_plots(X_clean, y_clean, model_fit=modelo)

# %% [markdown]
# boxcox  isolation forest

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Usar tus variables del modelo (NO el objeto modelo)
X_vif = X_clean.copy()

# Agregar constante
X_vif = sm.add_constant(X_vif)

vif_data = pd.DataFrame()
vif_data["Variable"] = X_vif.columns
vif_data["VIF"] = [
    variance_inflation_factor(X_vif.values, i)
    for i in range(X_vif.shape[1])
]

# Quitar la constante del análisis final
vif_data = vif_data[vif_data["Variable"] != "const"]

print("\n================ VIF =================")
print(vif_data.sort_values("VIF", ascending=False))
# Out:
# ================ VIF =================
#                           Variable           VIF
# 17          maximum_nights_avg_ntm  1.033030e+11
# 14          minimum_maximum_nights  4.397037e+10
# 15          maximum_maximum_nights  2.938401e+10
# 3              host_listings_count  1.785710e+01
# 4        host_total_listings_count  1.309950e+01
# 5   calculated_host_listings_count  9.003165e+00
# 22            review_scores_rating  7.185264e+00
# 16          minimum_nights_avg_ntm  4.533598e+00
# 23          review_scores_accuracy  4.466754e+00
# 13          maximum_minimum_nights  4.365920e+00
# 28             review_scores_value  4.209854e+00
# 26     review_scores_communication  3.084890e+00
# 8                  bedrooms_capped  3.062234e+00
# 6              accommodates_capped  2.887545e+00
# 24       review_scores_cleanliness  2.785045e+00
# 12          minimum_minimum_nights  2.511958e+00
# 25           review_scores_checkin  2.440582e+00
# 10                  minimum_nights  2.195929e+00
# 9                             beds  2.053590e+00
# 19               number_of_reviews  1.881269e+00
# 21       estimated_occupancy_l365d  1.707484e+00
# 27          review_scores_location  1.691332e+00
# 2             host_acceptance_rate  1.682511e+00
# 20               reviews_per_month  1.575973e+00
# 7                        bathrooms  1.487121e+00
# 1               host_response_rate  1.413145e+00
# 11                  maximum_nights  1.182491e+00
# 18                availability_365  1.065466e+00

# %%
num_features_clean = [

    # 🔹 Host (una sola de tamaño + métricas de comportamiento)
    "host_response_rate",
    "host_acceptance_rate",
   "calculated_host_listings_count",

    # 🔹 Propiedad (estructura real del alojamiento)
    "accommodates_capped",
    "bathrooms",
    "bedrooms_capped",

    # 🔹 Restricciones de estancia (solo lo esencial)
    "minimum_nights",
    "maximum_nights",

    # 🔹 Disponibilidad real
    "availability_365",

    # 🔹 Dinámica de reviews (actividad real)
    "reviews_per_month",

    # 🔹 Ocupación estimada
    "estimated_occupancy_l365d",

    # 🔹 Calidad general (evitamos multicolinealidad de sub-scores)
   "review_scores_rating"
]

# %%
# ==========================
# REGRESIÓN LINEAL DEFINITIVA
# ==========================

# 1️⃣ Variable objetivo
y = pd.to_numeric(df["price_log"], errors="coerce")

# 2️⃣ Asegurar que solo use variables que realmente existen en el df
num_features_existing = [c for c in num_features_clean if c in df.columns]

print("Variables usadas:", len(num_features_existing))
print(num_features_existing)

# 3️⃣ Construcción de X
X = df[num_features_existing].copy()

# convertir todo a numérico
X = X.apply(pd.to_numeric, errors="coerce")

# 4️⃣ Limpiar inf y NA (solo para el modelo)
data = (
    pd.concat([X, y.rename("price_log")], axis=1)
    .replace([np.inf, -np.inf], np.nan)
    .dropna()
)

X_clean = data.drop(columns=["price_log"]).astype("float64")
y_clean = data["price_log"].astype("float64")

print("Filas usadas para entrenar:", len(y_clean))

# 5️⃣ Modelo OLS
X_sm = sm.add_constant(X_clean, has_constant="add").astype("float64")
modelo = sm.OLS(y_clean, X_sm).fit()

# Forzar tipos numéricos válidos para statsmodels (evita dtype=object)
X_sm = sm.add_constant(X_clean, has_constant="add").astype(float)
y_clean = pd.to_numeric(y_clean, errors="coerce").astype(float)

# Alinear y limpiar por si quedó algún NaN
mask = y_clean.notna() & X_sm.notna().all(axis=1)
X_sm = X_sm.loc[mask]
y_clean = y_clean.loc[mask]

modelo = sm.OLS(y_clean, X_sm).fit()

# 6️⃣ Métricas adicionales
y_pred = modelo.predict(X_sm)

rmse = np.sqrt(mean_squared_error(y_clean, y_pred))
mae = mean_absolute_error(y_clean, y_pred)

print("\n================ MÉTRICAS =================")
print("R²:", modelo.rsquared)
print("R² Ajustado:", modelo.rsquared_adj)
print("RMSE:", rmse)
print("MAE:", mae)

print(modelo.summary())
# Out:
# Variables usadas: 11
# ['host_response_rate', 'host_acceptance_rate', 'calculated_host_listings_count', 'accommodates_capped', 'bathrooms', 'bedrooms_capped', 'minimum_nights', 'maximum_nights', 'availability_365', 'reviews_per_month', 'estimated_occupancy_l365d']
# Filas usadas para entrenar: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 34
#      32 # 5️⃣ Modelo OLS
#      33 X_sm = sm.add_constant(X_clean, has_constant="add").astype("float64")
# ---> 34 modelo = sm.OLS(y_clean, X_sm).fit()
#      36 # Forzar tipos numéricos válidos para statsmodels (evita dtype=object)
#      37 X_sm = sm.add_constant(X_clean, has_constant="add").astype(float)
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
#     922                           hasconst=hasconst, **kwargs)
#     923 if "weights" in self._init_keys:
#     924     self._init_keys.remove("weights")
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:746, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     744 else:
#     745     weights = weights.squeeze()
# --> 746 super().__init__(endog, exog, missing=missing,
#     747                           weights=weights, hasconst=hasconst, **kwargs)
#     748 nobs = self.exog.shape[0]
#     749 weights = self.weights
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:200, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     199 def __init__(self, endog, exog, **kwargs):
# --> 200     super().__init__(endog, exog, **kwargs)
#     201     self.pinv_wexog: Float64Array | None = None
#     202     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/data.py:694, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     691     exog = np.asarray(exog)
#     693 klass = handle_data_class_factory(endog, exog)
# --> 694 return klass(endog, exog=exog, missing=missing, hasconst=hasconst, **kwargs)
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/data.py:90, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      88 self.const_idx = None
#      89 self.k_constant = 0
# ---> 90 self._handle_constant(hasconst)
#      91 self._check_integrity()
#      92 self._cache = {}
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/statsmodels/base/data.py:137, in ModelData._handle_constant(self, hasconst)
#     134 else:
#     135     # detect where the constant is
#     136     check_implicit = False
# --> 137     exog_max = np.max(self.exog, axis=0)
#     138     if not np.isfinite(exog_max).all():
#     139         raise MissingDataError("exog contains inf or nans")
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3123, in max(a, axis, out, keepdims, initial, where)
#    3011 @array_function_dispatch(_max_dispatcher)
#    3012 @set_module('numpy')
#    3013 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3014          where=np._NoValue):
#    3015     """
#    3016     Return the maximum of an array or maximum along an axis.
#    3017
#    (...)   3121     5
#    3122     """
# -> 3123     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    3124                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/Documentos/2026 - 1/ANALITICA/TALLER 1/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:83, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      80         else:
#      81             return reduction(axis=axis, out=out, **passkwargs)
# ---> 83 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %% [markdown]
# # Sección 6:
